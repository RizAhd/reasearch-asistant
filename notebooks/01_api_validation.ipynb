# %%
import os
import sys
from dotenv import load_dotenv

# %%
sys.path.append('backend')

# %%
load_dotenv('../backend/.env')
# Out:
# True

# %%
print("✅ Environment loaded")
print(f"OpenAI Key exists: {'✅' if os.getenv('OPENAI_API_KEY') else '❌'}")
print(f"NewsAPI Key exists: {'✅' if os.getenv('NEWS_API_KEY') else '❌'}")
# Out:
# ✅ Environment loaded
# OpenAI Key exists: ✅
# NewsAPI Key exists: ✅

# %%
print("\n" + "="*50)
print("Testing OpenAI API...")
print("="*50)

try:
    from openai import OpenAI
    client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))
    
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "user", "content": "Say 'OpenAI is working!'"}],
        max_tokens=10
    )
    
    print(f"✅ OpenAI Response: {response.choices[0].message.content}")
    print(f"✅ Tokens used: {response.usage.total_tokens}")
    
except Exception as e:
    print(f"❌ OpenAI Error: {e}")
# Out:
# ...
# Testing OpenAI API...
# ...
# ✅ OpenAI Response: OpenAI is working!
# ✅ Tokens used: 19

# %%
print("\n" + "="*50)
print("Testing Wikipedia via MediaWiki API...")
print("="*50)

import requests

try:
    # MediaWiki API endpoint
    api_url = "https://en.wikipedia.org/w/api.php"
    
    params = {
        "action": "query",
        "format": "json",
        "prop": "extracts|info",
        "exintro": True,
        "explaintext": True,
        "titles": "Artificial intelligence",
        "inprop": "url"
    }
    
    headers = {
        'User-Agent': 'ResearchAssistant/1.0 (your@email.com)'
    }
    
    response = requests.get(api_url, params=params, headers=headers)
    
    if response.status_code == 200:
        data = response.json()
        pages = data.get("query", {}).get("pages", {})
        
        for page_id, page_info in pages.items():
            if page_id != "-1":  # Not a missing page
                print(f"✅ Title: {page_info.get('title')}")
                print(f"✅ Extract: {page_info.get('extract', '')[:100]}...")
                print(f"✅ URL: https://en.wikipedia.org/?curid={page_id}")
                break
        else:
            print("❌ Page not found")
    else:
        print(f"❌ API Error: HTTP {response.status_code}")
        
except Exception as e:
    print(f"❌ MediaWiki API Error: {e}")
# Out:
# ...
# Testing Wikipedia via MediaWiki API...
# ...
# ✅ Title: Artificial intelligence
# ✅ Extract: Artificial intelligence (AI) is the capability of computational systems to perform tasks typically a...
# ✅ URL: https://en.wikipedia.org/?curid=1164

# %%
print("\n" + "="*50)
print("Testing arXiv API...")
print("="*50)

import arxiv

try:
    client = arxiv.Client()
    search = arxiv.Search(
        query="artificial intelligence",
        max_results=1,
        sort_by=arxiv.SortCriterion.Relevance
    )
    
    results = list(client.results(search))
    if results:
        paper = results[0]
        print(f"✅ arXiv Paper: {paper.title[:50]}...")
        print(f"✅ Authors: {', '.join([str(a) for a in paper.authors[:2]])}")
    else:
        print("✅ arXiv API works but no results")
        
except Exception as e:
    print(f"❌ arXiv Error: {e}")

# Cell 5: Test NewsAPI
print("\n" + "="*50)
print("Testing NewsAPI...")
print("="*50)

NEWS_API_KEY = os.getenv('NEWS_API_KEY')

if NEWS_API_KEY:
    try:
        news_url = "https://newsapi.org/v2/everything"
        params = {
            "q": "AI",
            "apiKey": NEWS_API_KEY,
            "pageSize": 1
        }
        
        response = requests.get(news_url, params=params)
        
        if response.status_code == 200:
            data = response.json()
            if data.get('articles'):
                article = data['articles'][0]
                print(f"✅ News Source: {article.get('source', {}).get('name')}")
                print(f"✅ Title: {article.get('title', '')[:50]}...")
            else:
                print("✅ NewsAPI works but no articles")
        else:
            print(f"❌ NewsAPI Error: HTTP {response.status_code}")
            
    except Exception as e:
        print(f"❌ NewsAPI Error: {e}")
else:
    print("⚠️ NewsAPI key not found in .env")
# Out:
# ...
# Testing arXiv API...
# ...
# ✅ arXiv Paper: The Artificial Scientist: Logicist, Emergentist, a...
# ✅ Authors: Michael Timothy Bennett, Yoshihiro Maruyama
#
# ...
# Testing NewsAPI...
# ...
# ✅ NewsAPI works but no articles

# %%
print("\n" + "="*50)
print("VALIDATION SUMMARY")
print("="*50)
# Out:
# ...
# VALIDATION SUMMARY
# ...

# %%
print("\n📊 All API tests completed!")
print("Check above for ✅ success or ❌ error indicators.")
print("\nNext steps:")
print("1. Fix any ❌ errors above")
print("2. Run notebook 02_openai_test.ipynb")
print("3. Build the main application")
# Out:
# 📊 All API tests completed!
# Check above for ✅ success or ❌ error indicators.
#
# Next steps:
# 1. Fix any ❌ errors above
# 2. Run notebook 02_openai_test.ipynb
# 3. Build the main application
